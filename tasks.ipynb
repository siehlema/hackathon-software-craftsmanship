# %%
# !pip install pylint
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 521.8/521.8 kB 9.9 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 274.6/274.6 kB 15.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 119.4/119.4 kB 6.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 92.3/92.3 kB 5.7 MB/s eta 0:00:00
# ...

# %%
# !pylint test.py
# Out:
# ************* Module test
# test.py:5:0: C0304: Final newline missing (missing-final-newline)
# test.py:1:0: C0114: Missing module docstring (missing-module-docstring)
#
# -----------------------------------
# Your code has been rated at 5.00/10

# %%
def add(a, b):
  return a + b

def sub(a, b):
  return a - b

def mul(a, b):
  return a * b

def div(a, b):
  return a / b

# %% [markdown]
# # Neuer Abschnitt
